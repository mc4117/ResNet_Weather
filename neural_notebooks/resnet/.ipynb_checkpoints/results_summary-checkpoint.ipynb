# %% [markdown]
# ## Residual

# %% [markdown]
# | Number of residual blocks | Number of variables | Dropout? | Ensemble do | Ensemble model | RMSE z500 | RMSE t850| Notebook |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1|  2 | No | 0 | 1 | 654.8 | 2.991 | resnet_small|
# | 1|  2 | Yes | 1 | 1 | 659.6 | 3.011 | resnet_small_do|
# | 1|  2 | Yes | 30 | 1 | 651.5 | 2.969 | resnet_small_do|
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 2|  2 | No | 0 | 1 | 595.2 | 2.762 | resnet_gen_no_do |
# | 2|  2 | Yes | 1 | 1 | 607.3 | 2.831 | resnet_gen_do |
# | 2|  2 | Yes | 30 | 1 | 594.1 | 2.77 |resnet_gen_do|
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 3|  2 | No | 0 | 1 | 553.1 | 2.649 | 72_resnet |
# | 3|  10 | No | 0 | 1 | 516.9 | 2.463 | 72_more_data |
# | 3|  10 | No | 0 | 4 | 500.3 | 2.397 | 72_more_data |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 5|  2 | No | 0 | 1 | 495.0 | 2.485 | resnet_5blocks |
# | 5|  2 | Yes | 1 | 1 | 497.1 | 2.523 | resnet_5blocks |
# | 5|  2 | Yes | 30 | 1 |  473.3 | 2.43  | resnet_5blocks |
# | 5|  10 | Yes | 1 | 1 | 461.2 | 2.372 | more_data_5blocks |
# | 5|  10 | Yes | 12 | 1 | 435.1 | 2.27 | more_data_5blocks |
# | 5|  10 | Yes | 24 | 2 | 428.8 | 2.248 | more_data_5blocks |
# | 5|  10 | Yes | 48 | 4 | 427.3 | 2.244 | more_data_5blocks |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 7|  2 | No | 0 | 1 | 479.4 | 2.456 | resnet_7blocks |
# | 7|  2 | Yes | 1 | 1 | 476.6 | 2.47 | resnet_7blocks |
# | 7|  2 | Yes | 30 | 1 | 451.7 | 2.374 | resnet_7blocks |
# | 7|  10 | Yes | 1 | 1 | 435.6 | 2.308 | more_data_7blocks |
# | 7|  10 | Yes | 12 | 1 | 408.0 | 2.202 | more_data_7blocks |
# | 7|  10 | Yes | 24 | 2 | 403.2 | 2.187 | more_data_7blocks |
# | 7|  10 | Yes | 48 | 4 | 399.6 | 2.172 | more_data_7blocks |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 9|  2 | No | 0 | 1 | 473.5 | 2.414 | resnet_gen_no_do |
# | 9|  2 | Yes | 1 | 1 | 470.9 | 2.452 | resnet_gen_do |
# | 9|  2 | Yes | 30 | 1 | 445.9 | 2.356 |resnet_gen_do|
# | 9|  10 | Yes | 1 | 1 | 425.2 | 2.278 | more_data_9blocks |
# | 9|  10 | Yes | 12 | 1 | 396.5 | 2.161 | more_data_9blocks |
# | 9|  10 | Yes | 24 | 2 | 390.1 | 2.14| more_data_9blocks |
# | 9|  12 | Yes | 20 | 1 | 385.8 | 2.165| more_data_9blocks |
# | 9|  12 | Yes | 60 | 3 | 378.1 |2.139 | more_data_9blocks |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 11|  10 | Yes | 1 | 1 | 414.2 | 2.232 | more_data_11blocks |
# | 11|  10 | Yes | 12 | 1 | 385.7 | 2.119 | more_data_11blocks |
# | 11|  10 | Yes | 24 | 2 | 379.7 | 2.096 | more_data_11blocks |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 12|  2 | No | 0 | 1 | 471.5 | 2.399 | resnet_gen_no_do |
# | 12|  2 | Yes | 1 | 1 | 461.2 | 2.41 | resnet_gen_do |
# | 12|  2 | Yes | 30 | 1 | 435.7 | 2.311 | resnet_gen_do |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 15|  2 | Yes | 1 | 1 | 457.7 | 2.381 | resnet_15blocks |
# | 15|  2 | Yes | 30 | 1 | 430.8 | 2.275 | resnet_15blocks |
# | 15|  10 | Yes | 1 | 1 |406.5  | 2.196 | more_data_15blocks |
# | 15|  10 | Yes | 12 | 1 | 378.0 | 2.085 | more_data_15blocks |
# | 15|  10 | Yes | 24 | 1 | 369.6 | 2.052 | more_data_15blocks |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 19|  10 | Yes | 1 | 1 | 401.1 | 2.17 | more_data_19blocks |
# | 19|  10 | Yes | 12 | 1 | 372.9 | 2.057| more_data_19blocks |

# %% [markdown]
# ## Convolutional

# %% [markdown]
# Best result with 10 variables and ensemble of 4 is:
#
#     RMSE t850 = 2.656
#     RMSE z500 = 588.9
#
# ensemble/full_dataset_dr_72_more_data.ipynb

# %%
import pylab as plt

plt.plot([5, 7, 9, 11, 15, 19], [435.1, 408.0, 396.5, 385.7, 378, 372.9], '-*', label = '1 model')
plt.plot([5, 7, 9, 11, 15, 19], [428.8, 403.2, 390.1, 379.7, 369.6, ], '-*', label = '2 models')
plt.plot([5, 7, 9, 11], [427.3, 399.6, , ], '-*', label = '4 models')
plt.xlabel("Number of residual blocks")
plt.ylabel("RMSE z500")
plt.xlim([4.95, 19.05])
plt.show()
plt.plot([5, 7, 9, 11, 15, 19], [2.27, 2.202, 2.161, 2.119, 2.085, 2.057], '-*', label = '1 model')
plt.plot([5, 7, 9, 11, 15, 19], [2.248, 2.187, 2.14, 2.096, 2.052, ], '-*', label = '2 models')
plt.plot([5, 7, 9, 11], [2.244, 2.172, , ], '-*', label = '4 models')
plt.xlabel("Number of residual blocks")
plt.ylabel("RMSE T850")
plt.xlim([4.95, 19.05])
plt.show()
# Out:
#   File "<ipython-input-37-b0192769cd00>", line 4
#     plt.plot([5, 7, 9, 11, 15, 19], [428.8, 403.2, 390.1, 379.7, , ], '-*', label = '2 models')
#                                                                  ^
# SyntaxError: invalid syntax

# %%
# do vs no do 
plt.plot([1, 2, 5, 7, 9, 12], [654.8, 595.2, 495, 479.4, 473.5, 471.5], '-*', label = 'No dropout')
plt.plot([1, 2, 5, 7, 9, 12, 15], [659.6, 607.3, 497.1, 476.6, 470.9, 461.2, 457.7],  '-*', label = 'Dropout')
plt.plot([1, 2, 5, 7, 9, 12, 15], [651.5, 594.1, 473.3, 451.7, 445.9, 435.7, 430.8],  '-*', label = 'Ensemble of 30')
plt.xlabel("Number of residual blocks")
plt.ylabel("RMSE z500")
plt.legend()
plt.show()

plt.plot([1, 2, 5, 7, 9, 12], [2.991, 2.762, 2.485, 2.456, 2.414, 2.399],  '-*', label = 'No dropout')
plt.plot([1, 2, 5, 7, 9, 12, 15], [3.011, 2.831, 2.523, 2.47, 2.452, 2.41, 2.381],  '-*', label = 'Dropout')
plt.plot([1, 2, 5, 7, 9, 12, 15], [2.969, 2.77, 2.43, 2.374, 2.356, 2.311, 2.275],  '-*', label = 'Ensemble of 30')
plt.xlabel("Number of residual blocks")
plt.ylabel("RMSE T850")
plt.legend()
plt.show()

# %% [markdown]
# ## lead time 120

# %% [markdown]
# | Number of residual blocks | Number of variables | Dropout? | Ensemble do | Ensemble model | RMSE z500 | RMSE t850| Notebook |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 7|  10 | Yes | 1 | 1 | 678.4 | 3.066 | more_data_7blocks_120 |
# | 7|  10 | Yes | 12 | 1 | 653.6 | 2.974 | more_data_7blocks_120 |

# %%
# both beating IFS42
