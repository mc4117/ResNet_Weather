# %%
import numpy as np
import xarray as xr
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
from src.score import *
import re

import generate_data as gd

# %%
# resnet/annual_nn_res_multi.py

# %% [raw]
# if var_name == 'specific_humidity':
#     var_dict = {
#         'geopotential': ('z', [500]),
#         'temperature': ('t', [850]),
#         'specific_humidity': ('q', [500, 850])}
# elif var_name == '2m temp':
#     var_dict = {
#         'geopotential': ('z', [500]),
#         'temperature': ('t', [850]),
#         '2m_temperature': ('t2m', None)}
# elif var_name == 'solar rad':
#     var_dict = {
#         'geopotential': ('z', [500]),
#         'temperature': ('t', [850]),
#         'toa_incident_solar_radiation': ('tisr', None)}
# elif var_name == 'pot_vort':
#     var_dict = {
#         'geopotential': ('z', [500]),
#         'temperature': ('t', [850]),
#         'potential_vorticity': ('pv', [500, 850])}
# elif var_name == 'const':
#     var_dict = {
#         'geopotential': ('z', [500]),
#         'temperature': ('t', [850]),
#         'constants': ['lat2d', 'orography', 'lsm']}
# elif var_name == 'orig':
#     var_dict = {
#         'geopotential': ('z', [500]),
#         'temperature': ('t', [850])}

# %%
class PeriodicPadding2D(tf.keras.layers.Layer):
    def __init__(self, pad_width, **kwargs):
        super().__init__(**kwargs)
        self.pad_width = pad_width

    def call(self, inputs, **kwargs):
        if self.pad_width == 0:
            return inputs
        inputs_padded = tf.concat(
            [inputs[:, :, -self.pad_width:, :], inputs, inputs[:, :, :self.pad_width, :]], axis=2)
        # Zero padding in the lat direction
        inputs_padded = tf.pad(inputs_padded, [[0, 0], [self.pad_width, self.pad_width], [0, 0], [0, 0]])
        return inputs_padded

    def get_config(self):
        config = super().get_config()
        config.update({'pad_width': self.pad_width})
        return config


class PeriodicConv2D(tf.keras.layers.Layer):
    def __init__(self, filters,
                 kernel_size,
                 conv_kwargs={},
                 **kwargs, ):
        super().__init__(**kwargs)
        self.filters = filters
        self.kernel_size = kernel_size
        self.conv_kwargs = conv_kwargs
        if type(kernel_size) is not int:
            assert kernel_size[0] == kernel_size[1], 'PeriodicConv2D only works for square kernels'
            kernel_size = kernel_size[0]
        pad_width = (kernel_size - 1) // 2
        self.padding = PeriodicPadding2D(pad_width)
        self.conv = Conv2D(
            filters, kernel_size, padding='valid', **conv_kwargs
        )

    def call(self, inputs):
        return self.conv(self.padding(inputs))

    def get_config(self):
        config = super().get_config()
        config.update({'filters': self.filters, 'kernel_size': self.kernel_size, 'conv_kwargs': self.conv_kwargs})
        return config

# %%
def convblock(inputs, f, k, dr = 0):
    x = inputs
    x = PeriodicConv2D(f, k)(x)
    x = LeakyReLU()(x)
    if dr>0: x = Dropout(dr)(x)
    return x

def build_resnet_cnn(filters, kernels, input_shape, dr=0, skip = True):
    """Fully convolutional residual network"""

    x = input = Input(shape=input_shape)
    x = convblock(x, filters[0], kernels[0])

    #Residual blocks
    for f, k in zip(filters[1:-1], kernels[1:-1]):
        y = x
        for _ in range(2):
            x = convblock(x, f, k)
        if skip: x = Add()([y, x])

    output = PeriodicConv2D(filters[-1], kernels[-1])(x)
    
    return keras.models.Model(input, output)

def create_predictions(model, dg):
    """Create non-iterative predictions"""
    preds_un = xr.DataArray(
        model.predict(dg),
        dims=['time', 'lat', 'lon', 'level'],
        coords={'time': dg.valid_time, 'lat': dg.data.lat, 'lon': dg.data.lon,
                'level': dg.data.isel(level=dg.output_idxs).level,
                'level_names': dg.data.isel(level=dg.output_idxs).level_names
               },
    )
    # Unnormalize
    preds = (preds_un * dg.std.isel(level=dg.output_idxs).values +
             dg.mean.isel(level=dg.output_idxs).values)
    unique_vars = list(set([l.split('_')[0] for l in preds.level_names.values])); unique_vars

    das = []
    for v in unique_vars:
        idxs = [i for i, vv in enumerate(preds.level_names.values) if vv.split('_')[0] in v]
        #print(v, idxs)
        da = preds.isel(level=idxs).squeeze().drop('level_names')
        if not 'level' in da.dims: da.drop('level')
        das.append({v: da})
    return preds_un, xr.merge(das, compat = 'override').drop('level')

# %%
def predictions(var_name, valid):
    dg_train, dg_valid, dg_test = gd.create_data(var_name)

    if var_name == 'specific_humidity':
        cnn = build_resnet_cnn([64, 64, 64, 64, 2], [5, 5, 5, 5, 5], (32, 64, 4))
    elif var_name == 'pot_vort':
        cnn = build_resnet_cnn([64, 64, 64, 64, 2], [5, 5, 5, 5, 5], (32, 64, 4))
    elif var_name == 'const':
        cnn = build_resnet_cnn([64, 64, 64, 64, 2], [5, 5, 5, 5, 5], (32, 64, 5))
    elif var_name == 'orig':
        cnn = build_resnet_cnn([64, 64, 64, 64, 2], [5, 5, 5, 5, 5], (32, 64, 2))
    else:
        cnn = build_resnet_cnn([64, 64, 64, 64, 2], [5, 5, 5, 5, 5], (32, 64, 3))

    cnn.compile(keras.optimizers.Adam(1e-4), 'mse')

    cnn.load_weights('/rds/general/user/mc4117/home/WeatherBench/saved_models/72_gpu_annual_res_' + str(var_name) + '.h5')

    number_of_forecasts = 1

    pred_ensemble=np.ndarray(shape=(2, 17448, 32, 64, number_of_forecasts),dtype=np.float32)
    print(pred_ensemble.shape)
    forecast_counter=np.zeros(number_of_forecasts,dtype=int)

    for j in range(number_of_forecasts):
        print(j)
        preds, output = create_predictions(cnn, dg_test)
        pred2 = np.asarray(output.to_array(), dtype=np.float32).squeeze()
        pred_ensemble[:,:,:,:,j]=pred2
        forecast_counter[j]=j+1
        filename2 = '/rds/general/user/mc4117/ephemeral/saved_pred/72_resnet_annual' + str(var_name)
        np.save(filename2 + '.npy', pred_ensemble)
        


    return preds, compute_weighted_rmse(output, valid).compute()

# %%
DATADIR = '/rds/general/user/mc4117/home/WeatherBench/data/'

z500_valid = load_test_data(f'{DATADIR}geopotential_500', 'z')
t850_valid = load_test_data(f'{DATADIR}temperature_850', 't')
valid = xr.merge([z500_valid, t850_valid])

# %%
preds_orig, rmse = predictions('orig', valid)
rmse
# Out:
# Loading data into RAM
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.221
#     z        float64 699.9

# %%
preds_sh, rmse_sh = predictions('specific_humidity', valid)
rmse_sh
# Out:
# Loading data into RAM
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.263
#     z        float64 714.3

# %%
preds_pv, rmse_pv = predictions('pot_vort', valid)
rmse_pv
# Out:
# Loading data into RAM
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.233
#     z        float64 707.3

# %%
preds_const, rmse_const = predictions('const', valid)
rmse_const
# Out:
# Loading data into RAM
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.174
#     z        float64 709.0

# %%
preds_2mt, rmse_2mt = predictions('2m temp', valid)
rmse_2mt
# Out:
# Loading data into RAM
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.193
#     z        float64 699.4

# %%
preds_sr, rmse_sr = predictions('solar rad', valid)
rmse_sr
# Out:
# Loading data into RAM
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.223
#     z        float64 698.1

# %%
dg_train, dg_valid, dg_test = gd.create_data('orig')
X1, y1 = dg_test[0]

for i in range(1, len(dg_test)):
    X2, y2 = dg_test[i]
    y1 = np.concatenate((y1, y2))
# Out:
# Loading data into RAM
# Loading data into RAM
# Loading data into RAM

# %%
real_unnorm =y1* dg_test.std.isel(level=[0,1]).values+dg_test.mean.isel(level=[0,1]).values

real_ds = xr.Dataset({
    'z': xr.DataArray(
        real_unnorm[..., 0],
        dims=['time', 'lat', 'lon'],
        coords={'time':dg_test.data.time[72:], 'lat': dg_test.data.lat, 'lon': dg_test.data.lon,
                },
    ),
    't': xr.DataArray(
        real_unnorm[..., 1],
        dims=['time', 'lat', 'lon'],
        coords={'time':dg_test.data.time[72:], 'lat': dg_test.data.lat, 'lon': dg_test.data.lon,
                },
    )
})

# %%
stack_test_list = [preds_orig, preds_sh, preds_pv, preds_const, preds_2mt,  preds_sr]

stack_total = sum(stack_test_list)/len(stack_test_list)

preds_total_un = xr.DataArray(
    stack_total,
    dims=['time', 'lat', 'lon', 'level'],
    coords={'time': dg_test.valid_time, 'lat': dg_test.data.lat, 'lon': dg_test.data.lon,
            'level': dg_test.data.isel(level=dg_test.output_idxs).level,
            'level_names': dg_test.data.isel(level=dg_test.output_idxs).level_names
            },
    )
# Unnormalize
preds_total = (preds_total_un * dg_test.std.isel(level=dg_test.output_idxs).values +
             dg_test.mean.isel(level=dg_test.output_idxs).values)
unique_vars = list(set([l.split('_')[0] for l in preds_total.level_names.values])); unique_vars

das = []
for v in unique_vars:
    idxs = [i for i, vv in enumerate(preds_total.level_names.values) if vv.split('_')[0] in v]
    da = preds_total.isel(level=idxs).squeeze().drop('level_names')
    if not 'level' in da.dims: da.drop('level')
    das.append({v: da})
fc_unnorm_total = xr.merge(das, compat = 'override').drop('level')

# %%
compute_weighted_rmse(fc_unnorm_total, real_ds).compute()
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.116
#     z        float64 681.0

# %%
unnorm_pred_list = []

var_list = [preds_orig, preds_sh, preds_pv, preds_const, preds_2mt, preds_sr]

for var in var_list:
    
    preds_un = xr.DataArray(
        var,
        dims=['time', 'lat', 'lon', 'level'],
        coords={'time': dg_test.valid_time, 'lat': dg_test.data.lat, 'lon': dg_test.data.lon,
                'level': dg_test.data.isel(level=dg_test.output_idxs).level,
                'level_names': dg_test.data.isel(level=dg_test.output_idxs).level_names
               },
    )
    # Unnormalize
    preds = (preds_un * dg_test.std.isel(level=dg_test.output_idxs).values +
             dg_test.mean.isel(level=dg_test.output_idxs).values)
    unique_vars = list(set([l.split('_')[0] for l in preds.level_names.values])); unique_vars

    das = []
    for v in unique_vars:
        idxs = [i for i, vv in enumerate(preds.level_names.values) if vv.split('_')[0] in v]
        #print(v, idxs)
        da = preds.isel(level=idxs).squeeze().drop('level_names')
        if not 'level' in da.dims: da.drop('level')
        das.append({v: da})
    fc_unnorm = xr.merge(das, compat = 'override').drop('level')

    unnorm_pred_list.append(fc_unnorm)

# %%
stack_mean = unnorm_pred_list[0].copy()

rmse_list = []

rmse_list.append(compute_weighted_rmse(stack_mean, real_ds).compute())
for i in range(1, len(unnorm_pred_list)):
    stack_mean += unnorm_pred_list[i].copy()
    rmse_list.append(compute_weighted_rmse(stack_mean/(i+1), real_ds).compute())

# %%
import pylab as plt

# effect of doing ensembles
plt.plot([i +1 for i in range(len(rmse_list))], [rmse_list[i].z for i in range(len(rmse_list))])
plt.xlabel('Number of ensembles')
plt.ylabel('RMSE_z500')
plt.show()

plt.plot([i +1 for i in range(len(rmse_list))], [rmse_list[i].t for i in range(len(rmse_list))])
plt.xlabel('Number of ensembles')
plt.ylabel('RMSE_t850')
plt.show()

# %%
# rmse_z = [rmse_list[i].z for i in range(len(rmse_list))]
diff_rmse_z = [rmse_z[i]-rmse_z[i+1] for i in range(len(rmse_z)-1)]
plt.semilogy(['sh', 'pv', 'const', '2mt', 'sr'], diff_rmse_z)
plt.show()
rmse_t = [rmse_list[i].t for i in range(len(rmse_list))]
diff_rmse_t = [rmse_t[i]-rmse_t[i+1] for i in range(len(rmse_t)-1)]
plt.semilogy(['sh', 'pv', 'const', '2mt', 'sr'], diff_rmse_t)
plt.show()

# so constants have the biggest effect in this small sample

# %%
from tensorflow.keras.layers import concatenate

def my_init(shape, dtype=None):
    print(shape)
    return tf.ones(shape, dtype=dtype)/6

def build_stack_model(input_shape, stack_list):
    # concatenate merge output from each model
    input_list = [Input(shape=input_shape) for i in range(len(stack_list))]
    merge = concatenate(input_list)
    hidden = Dense(6, activation='relu', kernel_initializer = my_init, bias_initializer = tf.zeros)(merge)
    #hidden = Dense(64, activation='relu')(hidden)
    output = Dense(2)(hidden)
    return keras.models.Model(input_list, output)

# %%
dg_train, dg_valid, dg_test = gd.create_data('orig')
X1, y1 = dg_test[0]

for i in range(1, len(dg_test)):
    X2, y2 = dg_test[i]
    y1 = np.concatenate((y1, y2))

stack_out = np.stack([preds_orig, preds_sh, preds_pv, preds_const, 
                      preds_2mt,  preds_sr])  

stack_test_list = []

for i in range(6):
    stack_test_list.append(stack_out[i])
# Out:
# Loading data into RAM
# Loading data into RAM
# Loading data into RAM

# %%
ensemble_model = build_stack_model((32, 64, 2), stack_test_list)

ensemble_model.compile(keras.optimizers.Adam(1e-4), 'mse')

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
                        monitor='val_loss',
                        min_delta=0,
                        patience=5,
                        verbose=1, 
                        mode='auto'
                    )

reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
            monitor = 'val_loss',
            patience=2,
            factor=0.2,
            verbose=1)  

ensemble_model.fit(x = stack_test_list, y = y1, epochs = 200, validation_split = 0.2, shuffle = True
                  , callbacks = [early_stopping_callback, reduce_lr_callback
                    ]) #, callbacks = [callback])
# Out:
# [12, 6]
# Train on 13958 samples, validate on 3490 samples
# Epoch 1/200
# 13958/13958 [==============================] - 18s 1ms/sample - loss: 4.3284 - val_loss: 3.0053
# Epoch 2/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 2.3540 - val_loss: 1.8111
# Epoch 3/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 1.5221 - val_loss: 1.2568
# Epoch 4/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 1.0951 - val_loss: 0.9386
# Epoch 5/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.8387 - val_loss: 0.7433
# Epoch 6/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.6872 - val_loss: 0.6370
# Epoch 7/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.6040 - val_loss: 0.5689
# Epoch 8/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.5450 - val_loss: 0.5188
# Epoch 9/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.5015 - val_loss: 0.4807
# Epoch 10/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.4672 - val_loss: 0.4490
# Epoch 11/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.4379 - val_loss: 0.4211
# Epoch 12/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.4118 - val_loss: 0.3959
# Epoch 13/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.3882 - val_loss: 0.3730
# Epoch 14/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.3667 - val_loss: 0.3521
# Epoch 15/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.3471 - val_loss: 0.3329
# Epoch 16/200
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.3291 - val_loss: 0.3153
# Epoch 17/200
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.3126 - val_loss: 0.2991
# Epoch 18/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.2974 - val_loss: 0.2842
# Epoch 19/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.2835 - val_loss: 0.2704
# Epoch 20/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.2705 - val_loss: 0.2576
# Epoch 21/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.2583 - val_loss: 0.2455
# Epoch 22/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.2468 - val_loss: 0.2339
# Epoch 23/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.2355 - val_loss: 0.2224
# Epoch 24/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.2240 - val_loss: 0.2103
# Epoch 25/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.2114 - val_loss: 0.1967
# Epoch 26/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.1963 - val_loss: 0.1802
# Epoch 27/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.1780 - val_loss: 0.1624
# Epoch 28/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.1619 - val_loss: 0.1497
# Epoch 29/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.1497 - val_loss: 0.1388
# Epoch 30/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.1391 - val_loss: 0.1292
# Epoch 31/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.1303 - val_loss: 0.1212
# Epoch 32/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.1226 - val_loss: 0.1140
# Epoch 33/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.1157 - val_loss: 0.1074
# Epoch 34/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.1095 - val_loss: 0.1015
# Epoch 35/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.1038 - val_loss: 0.0961
# Epoch 36/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0987 - val_loss: 0.0912
# Epoch 37/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0941 - val_loss: 0.0868
# Epoch 38/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0898 - val_loss: 0.0828
# Epoch 39/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0860 - val_loss: 0.0793
# Epoch 40/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0826 - val_loss: 0.0761
# Epoch 41/200
# 13958/13958 [==============================] - 18s 1ms/sample - loss: 0.0795 - val_loss: 0.0732
# Epoch 42/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0766 - val_loss: 0.0707
# Epoch 43/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0741 - val_loss: 0.0683
# Epoch 44/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0718 - val_loss: 0.0663
# Epoch 45/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0697 - val_loss: 0.0645
# Epoch 46/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0678 - val_loss: 0.0629
# Epoch 47/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0661 - val_loss: 0.0614
# Epoch 48/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0646 - val_loss: 0.0600
# Epoch 49/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0632 - val_loss: 0.0588
# Epoch 50/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0619 - val_loss: 0.0578
# Epoch 51/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0608 - val_loss: 0.0569
# Epoch 52/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0598 - val_loss: 0.0560
# Epoch 53/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0589 - val_loss: 0.0553
# Epoch 54/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0580 - val_loss: 0.0547
# Epoch 55/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0573 - val_loss: 0.0540
# Epoch 56/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0566 - val_loss: 0.0534
# Epoch 57/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0560 - val_loss: 0.0530
# Epoch 58/200
# 13958/13958 [==============================] - 17s 1ms/sample - loss: 0.0555 - val_loss: 0.0525
# Epoch 59/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0550 - val_loss: 0.0522
# Epoch 60/200
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.0546 - val_loss: 0.0518
# Epoch 61/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0542 - val_loss: 0.0514
# Epoch 62/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0538 - val_loss: 0.0513
# Epoch 63/200
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.0536 - val_loss: 0.0509
# Epoch 64/200
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.0533 - val_loss: 0.0508
# Epoch 65/200
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.0531 - val_loss: 0.0505
# Epoch 66/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0529 - val_loss: 0.0505
# Epoch 67/200
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.0527 - val_loss: 0.0503
# Epoch 68/200
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.0526 - val_loss: 0.0502
# Epoch 69/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0524 - val_loss: 0.0500
# Epoch 70/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0523 - val_loss: 0.0500
# Epoch 71/200
# 13952/13958 [============================>.] - ETA: 0s - loss: 0.0522
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0522 - val_loss: 0.0500
# Epoch 72/200
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.0522 - val_loss: 0.0499
# Epoch 73/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0522 - val_loss: 0.0499
# Epoch 74/200
# 13952/13958 [============================>.] - ETA: 0s - loss: 0.0522
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0522 - val_loss: 0.0499
# Epoch 75/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0522 - val_loss: 0.0499
# Epoch 76/200
# 13952/13958 [============================>.] - ETA: 0s - loss: 0.0521
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.0521 - val_loss: 0.0499
# Epoch 77/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0521 - val_loss: 0.0499
# Epoch 78/200
# 13952/13958 [============================>.] - ETA: 0s - loss: 0.0521
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 13958/13958 [==============================] - 15s 1ms/sample - loss: 0.0521 - val_loss: 0.0499
# Epoch 79/200
# 13958/13958 [==============================] - 16s 1ms/sample - loss: 0.0521 - val_loss: 0.0499
# Epoch 00079: early stopping

# %% [markdown]
# ## training error

# %%
    fc = ensemble_model.predict(stack_test_list)
    preds_un = xr.DataArray(
        fc,
        dims=['time', 'lat', 'lon', 'level'],
        coords={'time': dg_test.valid_time, 'lat': dg_test.data.lat, 'lon': dg_test.data.lon,
                'level': dg_test.data.isel(level=dg_test.output_idxs).level,
                'level_names': dg_test.data.isel(level=dg_test.output_idxs).level_names
               },
    )
    # Unnormalize
    preds = (preds_un * dg_test.std.isel(level=dg_test.output_idxs).values +
             dg_test.mean.isel(level=dg_test.output_idxs).values)
    unique_vars = list(set([l.split('_')[0] for l in preds.level_names.values])); unique_vars

    das = []
    for v in unique_vars:
        idxs = [i for i, vv in enumerate(preds.level_names.values) if vv.split('_')[0] in v]
        #print(v, idxs)
        da = preds.isel(level=idxs).squeeze().drop('level_names')
        if not 'level' in da.dims: da.drop('level')
        das.append({v: da})
    fc_unnorm = xr.merge(das, compat = 'override').drop('level')

# %%
real_unnorm =y1* dg_test.std.isel(level=[0,1]).values+dg_test.mean.isel(level=[0,1]).values

real_ds = xr.Dataset({
    'z': xr.DataArray(
        real_unnorm[..., 0],
        dims=['time', 'lat', 'lon'],
        coords={'time':dg_test.data.time[72:], 'lat': dg_test.data.lat, 'lon': dg_test.data.lon,
                },
    ),
    't': xr.DataArray(
        real_unnorm[..., 1],
        dims=['time', 'lat', 'lon'],
        coords={'time':dg_test.data.time[72:], 'lat': dg_test.data.lat, 'lon': dg_test.data.lon,
                },
    )
})

# %%
compute_weighted_rmse(fc_unnorm, real_ds).compute()
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.105
#     z        float64 681.2

# %% [markdown]
# ## validation error

# %%
def predictions_sec(var_name, valid):
    dg_test = gd.create_data_second_test(var_name)

    if var_name == 'specific_humidity':
        cnn = build_resnet_cnn([64, 64, 64, 64, 2], [5, 5, 5, 5, 5], (32, 64, 4))
    elif var_name == 'pot_vort':
        cnn = build_resnet_cnn([64, 64, 64, 64, 2], [5, 5, 5, 5, 5], (32, 64, 4))
    elif var_name == 'const':
        cnn = build_resnet_cnn([64, 64, 64, 64, 2], [5, 5, 5, 5, 5], (32, 64, 5))
    elif var_name == 'orig':
        cnn = build_resnet_cnn([64, 64, 64, 64, 2], [5, 5, 5, 5, 5], (32, 64, 2))
    else:
        cnn = build_resnet_cnn([64, 64, 64, 64, 2], [5, 5, 5, 5, 5], (32, 64, 3))

    cnn.compile(keras.optimizers.Adam(1e-4), 'mse')

    cnn.load_weights('/rds/general/user/mc4117/home/WeatherBench/saved_models/72_gpu_annual_res_' + str(var_name) + '.h5')

    number_of_forecasts = 1

    pred_ensemble=np.ndarray(shape=(2, 17448, 32, 64, number_of_forecasts),dtype=np.float32)
    print(pred_ensemble.shape)
    forecast_counter=np.zeros(number_of_forecasts,dtype=int)

    for j in range(number_of_forecasts):
        print(j)
        preds, output = create_predictions(cnn, dg_test)
        pred2 = np.asarray(output.to_array(), dtype=np.float32).squeeze()
        pred_ensemble[:,:,:,:,j]=pred2
        forecast_counter[j]=j+1
        filename2 = '/rds/general/user/mc4117/ephemeral/saved_pred/72_resnet_annual' + str(var_name)
        np.save(filename2 + '.npy', pred_ensemble)
        


    return preds, compute_weighted_rmse(output, valid).compute()

# %%
z500_valid = load_test_data(f'{DATADIR}geopotential_500', 'z', years = slice('2013', '2014'))
t850_valid = load_test_data(f'{DATADIR}temperature_850', 't', years = slice('2013', '2014'))
valid2 = xr.merge([z500_valid, t850_valid])

# %%
preds_orig_sec, rmse_sec = predictions_sec('orig', valid2)
print(rmse_sec)
preds_sh_sec, rmse_sec = predictions_sec('specific_humidity', valid2)
print(rmse_sec)
preds_sr_sec, rmse_sec = predictions_sec('solar rad', valid2)
print(rmse_sec)
preds_pv_sec, rmse_sec = predictions_sec('pot_vort', valid2)
print(rmse_sec)
preds_const_sec, rmse_sec = predictions_sec('const', valid2)
print(rmse_sec)
preds_2mtmp_sec, rmse_sec = predictions_sec('2m temp', valid2)
print(rmse_sec)
# Out:
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.241
#     z        float64 695.4
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.282
#     z        float64 712.2
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.237
#     z        float64 692.8
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.256
#     z        float64 705.6
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.195
#     z        float64 706.8
# Loading data into RAM
# Loading data into RAM
# (2, 17448, 32, 64, 1)
# 0
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.207
#     z        float64 695.7

# %%
stack_out_sec = np.stack([preds_orig_sec, preds_sh_sec, preds_pv_sec, preds_const_sec, 
                      preds_2mtmp_sec,  preds_sr_sec])  

stack_test_list_sec = []

for i in range(6):
    stack_test_list_sec.append(stack_out_sec[i])

# %%
dg_valid2 = gd.create_data_second_test("orig")
# Out:
# Loading data into RAM
# Loading data into RAM

# %%
    fc_sec = ensemble_model.predict(stack_test_list_sec)
    preds_un_sec = xr.DataArray(
        fc_sec,
        dims=['time', 'lat', 'lon', 'level'],
        coords={'time': dg_valid2.valid_time, 'lat': dg_valid2.data.lat, 'lon': dg_valid2.data.lon,
                'level': dg_valid2.data.isel(level=dg_valid2.output_idxs).level,
                'level_names': dg_valid2.data.isel(level=dg_valid2.output_idxs).level_names
               },
    )
    # Unnormalize
    preds_sec = (preds_un_sec * dg_valid2.std.isel(level=dg_valid2.output_idxs).values +
             dg_valid2.mean.isel(level=dg_valid2.output_idxs).values)
    unique_vars = list(set([l.split('_')[0] for l in preds_sec.level_names.values])); unique_vars

    das = []
    for v in unique_vars:
        idxs = [i for i, vv in enumerate(preds_sec.level_names.values) if vv.split('_')[0] in v]
        #print(v, idxs)
        da = preds_sec.isel(level=idxs).squeeze().drop('level_names')
        if not 'level' in da.dims: da.drop('level')
        das.append({v: da})
    fc_unnorm_sec = xr.merge(das, compat = 'override').drop('level')

# %%
# stacked model

compute_weighted_rmse(fc_unnorm_sec, valid2).compute()
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.122
#     z        float64 677.3

# %%
# ensemble mean

unnorm_pred_list_sec = []

var_list_sec = [preds_orig_sec, preds_sh_sec, preds_pv_sec, preds_const_sec, preds_2mtmp_sec, preds_sr_sec]

for var in var_list_sec:
    
    preds = (var * dg_valid2.std.isel(level=dg_valid2.output_idxs).values +
             dg_valid2.mean.isel(level=dg_valid2.output_idxs).values)
    unique_vars = list(set([l.split('_')[0] for l in preds.level_names.values])); unique_vars

    das = []
    for v in unique_vars:
        idxs = [i for i, vv in enumerate(preds.level_names.values) if vv.split('_')[0] in v]
        #print(v, idxs)
        da = preds.isel(level=idxs).squeeze().drop('level_names')
        if not 'level' in da.dims: da.drop('level')
        das.append({v: da})
    unnorm_pred_list_sec.append(xr.merge(das, compat = 'override').drop('level'))

# %%
stack_mean_sec = unnorm_pred_list_sec[0].copy()

rmse_list_sec = []

rmse_list_sec.append(compute_weighted_rmse(stack_mean_sec, valid2).compute())
for i in range(1, len(unnorm_pred_list_sec)):
    stack_mean_sec += unnorm_pred_list_sec[i].copy()
    rmse_list_sec.append(compute_weighted_rmse(stack_mean_sec/(i+1), valid2).compute())

# %%
rmse_list_sec[-1]
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     t        float64 3.134
#     z        float64 677.6
