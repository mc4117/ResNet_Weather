# %%
import numpy as np
import xarray as xr
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
import itertools
from tensorflow.keras.utils import to_categorical
from src.score import *
import re
from collections import OrderedDict

# %%
DATADIR = '/rds/general/user/mc4117/home/WeatherBench/data/'

# %%
var_dict = {
        'geopotential': ('z', [500]),
        'temperature': ('t', [850])} 


ds_list = []

for long_var, params in var_dict.items():
    if long_var == 'constants':
        ds_list.append(xr.open_mfdataset(f'{DATADIR}/{long_var}/*.nc', combine='by_coords'))
    else:
        var, levels = params
        if levels is not None:
            ds_list.append(xr.open_mfdataset(f'{DATADIR}/{long_var}/*.nc', combine='by_coords').sel(level = levels))
        else:
            ds_list.append(xr.open_mfdataset(f'{DATADIR}/{long_var}/*.nc', combine='by_coords'))

# because missing first values of solar radiation exclude these from the dataset
ds_whole = xr.merge(ds_list).isel(time = slice(7, None))

ds_test = ds_whole.sel(time=slice('2017', '2018'))

# %%
block_no = 23
var_name = 'temp'
unique_list = [500, 600, 700, 850, 925, 1000]
temp_23 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')

# %%
compute_weighted_rmse(temp_23, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.16580794)
# Coordinates:
#     level    int64 850

# %%
block_no = 25
temp_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(temp_25, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.21518497)
# Coordinates:
#     level    int64 850

# %%
block_no = 27
temp_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(temp_27, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.21447342)
# Coordinates:
#     level    int64 850

# %%
block_no = 13
var_name = 'geo'
geo_13 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(geo_13, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.19827757)
# Coordinates:
#     level    int64 850

# %%
block_no = 17
geo_17 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(geo_17, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.22065815)
# Coordinates:
#     level    int64 850

# %%
block_no = 20
geo_20 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(geo_20, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.24994221)
# Coordinates:
#     level    int64 850

# %%
block_no = 23
geo_23 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(geo_23, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.20656841)
# Coordinates:
#     level    int64 850

# %%
block_no = 25
geo_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(geo_25, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.20628665)
# Coordinates:
#     level    int64 850

# %%
block_no = 27
geo_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(geo_27, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.16618329)
# Coordinates:
#     level    int64 850

# %%
block_no = 29
geo_29 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(geo_29, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.33804166)
# Coordinates:
#     level    int64 850

# %%
block_no = 31
geo_31 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(geo_31, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.19380978)
# Coordinates:
#     level    int64 850

# %%
block_no = 23
var_name = 'pot_vort'
unique_list = [150, 250, 300, 700, 850]
pv_23 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(pv_23, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.23988587)
# Coordinates:
#     level    int64 850

# %%
block_no = 25
pv_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(pv_25, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.21679463)
# Coordinates:
#     level    int64 850

# %%
block_no = 27
pv_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(pv_27, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.2231974)
# Coordinates:
#     level    int64 850

# %%
block_no = 23
var_name = 'specific_humidity'
unique_list = [150, 200, 600, 700, 850, 925, 1000]
sh_23 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(sh_23, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.24652773)
# Coordinates:
#     level    int64 850

# %%
block_no = 25
sh_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(sh_25, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.23192589)
# Coordinates:
#     level    int64 850

# %%
block_no = 27
sh_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(sh_27, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.25111272)
# Coordinates:
#     level    int64 850

# %%
block_no = 23
var_name = 'const'
unique_list = 'no_l'
const_23 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(const_23, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.27499678)
# Coordinates:
#     level    int64 850

# %%
block_no = 25
var_name = 'const'
unique_list = 'no_l'
const_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(const_25, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.28776712)
# Coordinates:
#     level    int64 850

# %%
block_no = 27
var_name = 'const'
unique_list = 'no_l'
const_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(const_27, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.42820955)
# Coordinates:
#     level    int64 850

# %%
block_no = 23
var_name = 'wind'
unique_list = [50, 100, 300, 850, 925, 1000]
wind_23 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(wind_23, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.22439842)
# Coordinates:
#     level    int64 850

# %%
block_no = 25
var_name = 'wind'
unique_list = [50, 100, 300, 850, 925, 1000]
wind_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(wind_25, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.18670894)
# Coordinates:
#     level    int64 850

# %%
block_no = 27
var_name = 'wind'
unique_list = [50, 100, 300, 850, 925, 1000]
wind_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_t_test.npy')
compute_weighted_rmse(wind_27, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.20389654)
# Coordinates:
#     level    int64 850

# %%
#ensemble

avg_25 = (temp_25 + wind_25 + geo_25 + pv_25 + sh_25 + const_25)/6
compute_weighted_rmse(avg_25, ds_test.t.sel(level = 850)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(2.12991833)
# Coordinates:
#     level    int64 850
