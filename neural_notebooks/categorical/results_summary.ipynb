# %% [markdown]
# ## Residual

# %% [markdown]
# | Number of residual blocks | Number of variables | Dropout? | Ensemble do | Ensemble model | RMSE z500 | RMSE t850| Notebook |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 5|  2 | No | 0 | 1 | 495.0 | 2.485 | resnet_5blocks |
# | 5|  2 | Yes | 1 | 1 | 497.1 | 2.523 | resnet_5blocks |
# | 5|  2 | Yes | 30 | 1 |  473.3 | 2.43  | resnet_5blocks |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 7|  2 | No | 0 | 1 | 479.4 | 2.456 | resnet_7blocks |
# | 7|  2 | Yes | 1 | 1 | 476.6 | 2.47 | resnet_7blocks |
# | 7|  2 | Yes | 30 | 1 | 451.7 | 2.374 | resnet_7blocks |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 9|  2 | No | 0 | 1 | 473.5 | 2.414 | resnet_gen_no_do |
# | 9|  2 | Yes | 1 | 1 | 470.9 | 2.452 | resnet_gen_do |
# | 9|  2 | Yes | 30 | 1 | 445.9 | 2.356 |resnet_gen_do|
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 12|  2 | No | 0 | 1 | 471.5 | 2.399 | resnet_gen_no_do |
# | 12|  2 | Yes | 1 | 1 | 461.2 | 2.41 | resnet_gen_do |
# | 12|  2 | Yes | 30 | 1 | 435.7 | 2.311 | resnet_gen_do |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 15|  2 | Yes | 0 | 1 | 467.8 | 2.393 | resnet_gen_no_do |
# | 15|  2 | Yes | 1 | 1 | 457.7 | 2.381 | resnet_15blocks |
# | 15|  2 | Yes | 30 | 1 | 430.8 | 2.275 | resnet_15blocks |

# %% [markdown]
# ### Categorical
# | Number of residual blocks | Number of variables | Dropout? | Ensemble do | Ensemble model | RMSE z500 | RMSE t850| Notebook |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 5|   2  | No | 0 | 1 | 524.3 | 2.687 | categorical whole_non_ohe_crossentropy.py
# | 5|   2  | Yes | 1 | 1 |  614 | 2.879 |
# | 5|   2  | Yes | 30 | 1 | 501.1 | 2.553 | |
# | 7|   2  | No | 0 | 1 | 502.1 | 2.636 | |
# | 7|   2  | Yes | 1 | 1 |  540.8 | 2.745 |
# | 7|   2  | Yes | 30 | 1 | 471.8 | 2.455 | |
# | 9|   2  | No | 0 | 1 | 490.9 | 2.603 | |
# | 9|   2  | Yes | 1 | 1 |  521.4 | 2.698 |
# | 9|   2  | Yes | 30 | 1 | 456.9 | 2.43 | |
# | 12|  2  | No | 0 | 1 | 485.9 | 2.592 | |
# | 12|   2  | Yes | 1 | 1 |  516.1 | 2.62 |
# | 12|   2  | Yes | 30 | 1 | 447.7 | 2.385 | |
# | 15|  2  | No | 0 | 1 | 483.9 | 2.589 | |
# | 15|   2  | Yes | 1 | 1 |  530.2| 2.572 |
# | 15|   2  | Yes | 30 | 1 | 452.0| 2.338 | |
# | 19| 2 | No | 0 | 1 | 481.4 | 2.593 | |

# %% [markdown]
# ### Categorical exp
# | Number of residual blocks | Number of variables | Dropout? | Ensemble do | Ensemble model | RMSE z500 | RMSE t850| Notebook |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 5|   2  | No | 0 | 1 | 509.9  | 2.485 |exp |
# | 5|   2  | Yes| 1 | 1 |   525.5    | 2.579| exp |
# | 5|   2  | Yes| 32 | 1 |    506.1   | 2.495| exp |
# | 7|   2  | No | 0 | 1 | 484.2  | 2.442 |exp |
# | 7|   2  | Yes| 1 | 1 |    498.1   | 2.485 |exp |
# | 7|   2  | Yes| 32 | 1 |    477.0   | 2.395 |exp |
# | 9|   2  | No | 0 | 1 |  483.4 | 2.417  |exp |
# | 9|   2  | Yes| 1 | 1 |   485.6   |  2.462  |exp |
# | 9|   2  | Yes| 32 | 1 |    462.2   | 2.369 |exp |
# | 12|  2  | No | 0 | 1 | 478.9 | 2.407    | exp |
# | 12|   2  | Yes| 1 | 1 |    485.7   | 2.416 |exp |
# | 12|   2  | Yes| 32 | 1 |   455.5    | 2.322 |exp |
# | 15| 2 | No | 0 | 1 | 477.2 | 2.408| exp |
# | 15|   2  | Yes| 1 | 1 |   528.1     | 2.384 |exp |
# | 15|   2  | Yes| 32 | 1 |   461.4   | 2.277 |exp |

# %%
import pylab as plt
plt.plot([5, 7, 9, 12, 15], [525.5, 498.1, 485.6, 485.7, 528.1 ], '-*', label = 'categorical single dr')
plt.plot([5, 7, 9, 12, 15], [506.1, 477, 462.2, 455.5, 461.4], '-*', label = 'categorical ensemble dr')
#plt.plot([5, 7, 9, 12, 15], [473.3, 451.7, 445.9, 435.7, 430.8], '-*', label = 'continuous ensemble dr')
plt.plot([5, 7, 9, 12, 15], [509.9, 484.2, 483.4, 478.9, 477.2], '-*', label = 'categorical no dr')
plt.plot([5, 7, 9, 12, 15], [489 for i in range(5)], ':', label = 'IFS T42')
plt.legend(ncol =2)
plt.xlabel("Number of residual blocks")
plt.ylabel("RMSE z500")
plt.show()

plt.plot([5, 7, 9, 12, 15], [2.579, 2.485, 2.462, 2.416, 2.384], '-*', label = 'categorical single dr')
plt.plot([5, 7, 9, 12, 15], [2.495, 2.395, 2.369, 2.322, 2.277], '-*', label = 'categorical ensemble dr')
#plt.plot([5, 7, 9, 12, 15], [2.43, 2.374, 2.356, 2.311, 2.275], '-*', label = 'continuous ensemble dr')
plt.plot([5, 7, 9, 12, 15], [2.485, 2.442, 2.417, 2.407, 2.408], '-*', label = 'categorical no dr')
plt.plot([5, 7, 9, 12, 15], [3.09 for i in range(5)], ':', label = 'IFS T42')
plt.xlabel("Number of residual blocks")
plt.ylabel("RMSE T850")
plt.legend(bbox_to_anchor=[0.1, 0.7], ncol =2, loc =3)
plt.show()

# %%
import pylab as plt

plt.plot([5, 7, 9, 12, 15], [509.9, 484.2, 483.4, 478.9, 477.2], '-*', label = 'categorical')
plt.plot([5, 7, 9, 12, 15], [495.0, 479.4, 473.5, 471.5, 467.8], '-*', label = 'continuous')
#plt.plot([5, 7, 9, 12, 15], [495.0+91.16, 479.4+91.16, 473.5+91.16, 471.5+91.16, 467.8+91.16], ':', label = 'inbuilt categorical error')
plt.xlabel("Number of residual blocks")
plt.ylabel("RMSE Z500")
plt.legend()
plt.show()

plt.plot([5, 7, 9, 12, 15], [2.485, 2.442, 2.417, 2.407, 2.408], '-*', label = 'categorical')
plt.plot([5, 7, 9, 12, 15], [2.485, 2.456, 2.414, 2.399, 2.393], '-*', label = 'continuous')
#plt.plot([5, 7, 9, 12, 15], [2.485+0.9923, 2.456+0.9923, 2.414+0.9923, 2.399+0.9923, 2.393+0.9923], ':', label = 'inbuilt categorical error')
plt.xlabel("Number of residual blocks")
plt.ylabel("RMSE T850")
plt.legend()
plt.show()

# %%
# 9 blocks
import pylab as plt
#plt.scatter([385.7], [2.164], marker = '*', label = 'continuous stacked')
plt.scatter([407.2], [2.211], marker = '*', label = 'stacked')
plt.scatter([421.4], [2.23], marker = '^', label = 'average')
plt.scatter([419.9], [2.27], facecolors='none', edgecolor = 'green', label = 'temperature')
plt.scatter([431.8], [2.253], facecolors='none', edgecolor = 'red', label = 'geopotential')
plt.scatter([442.8], [2.293], facecolors='none', edgecolor = 'violet', label = 'specific humidity')
plt.scatter([458.2], [2.322], facecolors='none', edgecolor = 'black', label = 'constant')
plt.scatter([428.8], [2.286], facecolors='none', edgecolor = 'blue', label = 'potential vorticity')
plt.ylabel("RMSE T850") 
plt.xlabel("RMSE z500") 
plt.legend()
plt.show()

# %%
import pylab as plt

# 25 blocks - 3 day t850 
plt.scatter('stacked', [2.110595], s = 75, marker = '*')
plt.scatter('average', [2.130], marker = '^')
plt.scatter('temperature', [2.215], color = 'green')
plt.scatter('geopotential', [2.206],  color = 'red')
plt.scatter('specific \n humidity', [2.232], color = 'magenta')
plt.scatter('potential \n vorticity', [2.217], color = 'black')
plt.scatter('horizontal \n wind', [2.187],  color = 'blue')
plt.scatter('constants', [2.288], color = 'orange')
plt.ylabel("RMSE T850") 
plt.xticks(rotation=45, ha="right")
plt.show()

# 25 blocks - 5 day t850 
plt.scatter('stacked', [2.907], s = 75, marker = '*')
plt.scatter('average', [2.929], marker = '^')
plt.scatter('temperature', [3.011], color = 'green')
plt.scatter('geopotential', [3.110],  color = 'red')
plt.scatter('specific \n humidity', [3.110], color = 'magenta')
plt.scatter('potential \n vorticity', [3.007], color = 'black')
plt.scatter('horizontal \n wind', [3.050],  color = 'blue')
plt.scatter('constants', [3.092], color = 'orange')
plt.ylabel("RMSE T850") 
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
# 29 blocks - 3 day z500 
plt.scatter('stacked', [375.4], s = 75, marker = '*')
plt.scatter('average', [396.4], marker = '^')
plt.scatter('temperature', [387.6], color = 'green')
plt.scatter('geopotential', [399.4],  color = 'red')
plt.scatter('specific \n humidity', [506.5], color = 'magenta')
plt.scatter('potential \n vorticity', [412.9], color = 'black')
plt.scatter('horizontal \n wind', [405.4],  color = 'blue')
plt.scatter('solar \n radiation', [616.1], color = 'mediumvioletred')
plt.scatter('constants', [444.0], color = 'orange')
plt.ylabel("RMSE Z500") 
plt.xticks(rotation=45, ha="right")
plt.show()

# 29 blocks - 5 day z500 
plt.scatter('stacked', [626.7],s = 75, marker = '*')
plt.scatter('average', [639.3], marker = '^')
plt.scatter('temperature', [661.9], color = 'green')
plt.scatter('geopotential', [661.5],  color = 'red')
plt.scatter('specific \n humidity', [687.6], color = 'magenta')
plt.scatter('potential \n vorticity', [662.8], color = 'black')
plt.scatter('horizontal \n wind', [740.8],  color = 'blue')
plt.scatter('solar \n radiation', [748.1], color = 'mediumvioletred')
plt.scatter('constants', [710.0], color = 'orange')
plt.ylabel("RMSE Z500") 
plt.xticks(rotation=45, ha="right")
plt.show()
