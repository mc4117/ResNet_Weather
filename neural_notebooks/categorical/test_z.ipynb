# %%
import numpy as np
import xarray as xr
import itertools
from tensorflow.keras.utils import to_categorical
from src.score import *
import re
from collections import OrderedDict

# %%
DATADIR = '/rds/general/user/mc4117/home/WeatherBench/data/'

# %%
var_dict = {
        'geopotential': ('z', [500]),
        'temperature': ('t', [850])}

# %%
ds_list = []

for long_var, params in var_dict.items():
    if long_var == 'constants':
        ds_list.append(xr.open_mfdataset(f'{DATADIR}/{long_var}/*.nc', combine='by_coords'))
    else:
        var, levels = params
        if levels is not None:
            ds_list.append(xr.open_mfdataset(f'{DATADIR}/{long_var}/*.nc', combine='by_coords').sel(level = levels))
        else:
            ds_list.append(xr.open_mfdataset(f'{DATADIR}/{long_var}/*.nc', combine='by_coords'))

# because missing first values of solar radiation exclude these from the dataset
ds_whole = xr.merge(ds_list).isel(time = slice(7, None))

ds_test = ds_whole.sel(time=slice('2017', '2018'))

# %%
block_no = 21
var_name = 'temp'
unique_list = [300, 400, 500, 600, 700, 850]
temp_21 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
temp_21.shape
compute_weighted_rmse(temp_21, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(387.94622692)
# Coordinates:
#     level    int64 500

# %%
block_no = 13
var_name = 'temp'
unique_list = [300, 400, 500, 600, 700, 850]
temp_13 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(temp_13, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(404.67330277)
# Coordinates:
#     level    int64 500

# %%
block_no = 17
var_name = 'temp'
unique_list = [300, 400, 500, 600, 700, 850]
temp_17 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(temp_17, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(390.71184932)
# Coordinates:
#     level    int64 500

# %%
block_no = 21
var_name = 'temp'
unique_list = [300, 400, 500, 600, 700, 850]
temp_21 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(temp_21, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(395.0387203)
# Coordinates:
#     level    int64 500

# %%
block_no = 23
var_name = 'temp'
unique_list = [300, 400, 500, 600, 700, 850]
temp_23 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(temp_23, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(406.89555113)
# Coordinates:
#     level    int64 500

# %%
block_no = 25
var_name = 'temp'
unique_list = [300, 400, 500, 600, 700, 850]
temp_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(temp_25, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(394.22508672)
# Coordinates:
#     level    int64 500

# %%
block_no = 27
var_name = 'temp'
unique_list = [300, 400, 500, 600, 700, 850]
temp_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(temp_27, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(393.38223816)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = 'temp'
unique_list = [300, 400, 500, 600, 700, 850]
temp_29 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(temp_29, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(387.55747828)
# Coordinates:
#     level    int64 500

# %%
block_no = 31
var_name = 'temp'
unique_list = [300, 400, 500, 600, 700, 850]
temp_31 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(temp_31, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(397.93775883)
# Coordinates:
#     level    int64 500

# %%
block_no = 25
var_name = 'geo'
unique_list = [300, 400, 500, 600, 700, 850]
geo_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(geo_25, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(396.51525902)
# Coordinates:
#     level    int64 500

# %%
block_no = 27
var_name = 'geo'
unique_list = [300, 400, 500, 600, 700, 850]
geo_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(geo_27, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(389.73900253)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = 'geo'
unique_list = [300, 400, 500, 600, 700, 850]
geo_29 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(geo_29, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(399.44396169)
# Coordinates:
#     level    int64 500

# %%
block_no = 25
var_name = "specific_humidity"
unique_list = [150, 200, 600, 700, 850, 925, 1000]
sh_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(sh_25, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(432.63153192)
# Coordinates:
#     level    int64 500

# %%
block_no = 27
var_name = "specific_humidity"
unique_list = [150, 200, 600, 700, 850, 925, 1000]
sh_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(sh_27, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(451.13204457)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = "specific_humidity"
unique_list = [150, 200, 600, 700, 850, 925, 1000]
sh_29 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(sh_29, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(506.49042521)
# Coordinates:
#     level    int64 500

# %%
block_no = 25
var_name = "pot_vort"
unique_list = [150, 250, 300, 700, 850]
pv_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(pv_25, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(415.67666868)
# Coordinates:
#     level    int64 500

# %%
block_no = 27
var_name = "pot_vort"
unique_list = [150, 250, 300, 700, 850]
pv_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(pv_27, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(416.30510167)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = "pot_vort"
unique_list = [150, 250, 300, 700, 850]
pv_29 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(pv_29, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(412.8674013)
# Coordinates:
#     level    int64 500

# %%
block_no = 25
var_name = 'const'
unique_list = 'no_l'
const_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(const_25, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(445.24499473)
# Coordinates:
#     level    int64 500

# %%
block_no = 27
var_name = 'const'
unique_list = 'no_l'
const_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(const_27, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(455.24239511)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = 'const'
unique_list = 'no_l'
const_29 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(const_29, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(443.98507726)
# Coordinates:
#     level    int64 500

# %%
block_no = 25
var_name = 'solar_rad'
unique_list = 'no_l'
sr_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(sr_25, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(455.39468074)
# Coordinates:
#     level    int64 500

# %%
block_no = 27
var_name = 'solar_rad'
unique_list = 'no_l'
sr_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(sr_27, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(462.74052974)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = 'solar_rad'
unique_list = 'no_l'
sr_29 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(sr_29, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(616.14572223)
# Coordinates:
#     level    int64 500

# %%
block_no = 25
var_name = 'wind'
unique_list = [50, 100, 300, 850, 925, 1000]
wind_25 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(wind_25, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(401.06553783)
# Coordinates:
#     level    int64 500

# %%
block_no = 27
wind_27 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(wind_27, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(401.50114019)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = 'wind'
unique_list = [50, 100, 300, 850, 925, 1000]
wind_29 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(wind_29, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(405.42674611)
# Coordinates:
#     level    int64 500

# %%
# ensemble

avg_29 = (temp_29 + wind_29 + geo_29 + pv_29 + sh_29 + const_29 + sr_29)/7
compute_weighted_rmse(avg_29, ds_test.z.sel(level = 500)[72:]).compute()
# Out:
# <xarray.DataArray ()>
# array(396.39087203)
# Coordinates:
#     level    int64 500

# %% [markdown]
# ### 5 days

# %%
block_no = 29
var_name = 'wind'
unique_list = [50, 100, 300, 850, 925, 1000]
wind_29_120 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/120_' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(wind_29_120, ds_test.z.sel(level = 500)[120:]).compute()
# Out:
# <xarray.DataArray ()>
# array(740.80374637)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = "specific_humidity"
unique_list = [150, 200, 600, 700, 850, 925, 1000]
sh_29_120 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/120_' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(sh_29_120, ds_test.z.sel(level = 500)[120:]).compute()
# Out:
# <xarray.DataArray ()>
# array(687.57001906)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = 'temp'
unique_list = [300, 400, 500, 600, 700, 850]
temp_29_120 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/120_' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(temp_29_120, ds_test.z.sel(level = 500)[120:]).compute()
# Out:
# <xarray.DataArray ()>
# array(661.9328499)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = 'geo'
unique_list = [300, 400, 500, 600, 700, 850]
geo_29_120 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/120_' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(geo_29_120, ds_test.z.sel(level = 500)[120:]).compute()
# Out:
# <xarray.DataArray ()>
# array(661.48153573)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = 'solar_rad'
unique_list = 'no_l'
sr_29_120 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/120_' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(sr_29_120, ds_test.z.sel(level = 500)[120:]).compute()
# Out:
# <xarray.DataArray ()>
# array(748.07123255)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = "pot_vort"
unique_list = [150, 250, 300, 700, 850]
pv_29_120 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/120_' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(pv_29_120, ds_test.z.sel(level = 500)[120:]).compute()
# Out:
# <xarray.DataArray ()>
# array(662.81598846)
# Coordinates:
#     level    int64 500

# %%
block_no = 29
var_name = 'const'
unique_list = 'no_l'
const_29_120 = np.load('/rds/general/user/mc4117/home/WeatherBench/saved_pred_data/120_' + str(block_no) + '_' + str(var_name) + '_' + str(unique_list) + '_preds_cat_test.npy')
compute_weighted_rmse(const_29_120, ds_test.z.sel(level = 500)[120:]).compute()
# Out:
# <xarray.DataArray ()>
# array(710.01650558)
# Coordinates:
#     level    int64 500

# %%
# ensemble

avg_29_120 = (temp_29_120 + wind_29_120 + geo_29_120 + pv_29_120 + sh_29_120 + const_29_120 + sr_29_120)/7
compute_weighted_rmse(avg_29_120, ds_test.z.sel(level = 500)[120:]).compute()
# Out:
# <xarray.DataArray ()>
# array(639.28386955)
# Coordinates:
#     level    int64 500
